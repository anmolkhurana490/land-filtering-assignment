# %%
# !pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pyproj-3.7.2-cp312-cp312-win_amd64.whl.metadata (31 kB)
# ...
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/22.9 MB 2.4 MB/s eta 0:00:10
#    - -------------------------------------- 1.0/22.9 MB 3.6 MB/s eta 0:00:07
#    - -------------------------------------- 1.0/22.9 MB 3.6 MB/s eta 0:00:07
#    -- ------------------------------------- 1.3/22.9 MB 1.7 MB/s eta 0:00:13
#    -- ------------------------------------- 1.6/22.9 MB 1.6 MB/s eta 0:00:14
#    --- ------------------------------------ 1.8/22.9 MB 1.4 MB/s eta 0:00:16
#    --- ------------------------------------ 1.8/22.9 MB 1.4 MB/s eta 0:00:16
#    --- ------------------------------------ 2.1/22.9 MB 1.2 MB/s eta 0:00:17
# ...

# %%
# !pip install fiona
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.5 MB 2.8 MB/s eta 0:00:09
#    - -------------------------------------- 1.0/24.5 MB 3.3 MB/s eta 0:00:07
#    -- ------------------------------------- 1.6/24.5 MB 2.5 MB/s eta 0:00:10
#    --- ------------------------------------ 1.8/24.5 MB 2.6 MB/s eta 0:00:09
#    --- ------------------------------------ 2.1/24.5 MB 2.2 MB/s eta 0:00:11
#    --- ------------------------------------ 2.1/24.5 MB 2.2 MB/s eta 0:00:11
#    ---- ----------------------------------- 2.6/24.5 MB 1.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 2.9/24.5 MB 1.7 MB/s eta 0:00:13
#    ---- ----------------------------------- 2.9/24.5 MB 1.7 MB/s eta 0:00:13
#    ----- ---------------------------------- 3.1/24.5 MB 1.4 MB/s eta 0:00:15
# ...

# %%
# Importing Libraries
import geopandas as gpd
import fiona

# %%
wetlands_layers = fiona.listlayers("TX_geodatabase_wetlands.gdb")
print(wetlands_layers)
# Out:
# ['Texas', 'TX_Wetlands_Historic_Map_Info', 'TX_Riparian', 'TX_Riparian_Project_Metadata', 'TX_Wetlands', 'TX_Wetlands_Project_Metadata']

# %%
# Handling Wetlands Data
gdf = gpd.read_file("TX_geodatabase_wetlands.gdb", layer="TX_Wetlands")
gdf.head()

# %%
gdf.shape
# Out:
# (1, 6)

# %%
gdf['geometry'][0]
# Out:
# <MULTIPOLYGON (((-285157.686 1261230.961, -285605.14 1247626.76, -274185.81 ...>

# %%
parcels_layers = fiona.listlayers("stratmap25-landparcels_48.gdb")
print(parcels_layers)
# Out:
# ['stratmap25_landparcels_48']

# %%
# Handling Wetlands Data
gdf = gpd.read_file("stratmap25-landparcels_48.gdb")
gdf.head()

# %%
gdf.to_file("texas_parcels.geojson", driver="GeoJSON")
